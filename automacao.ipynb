# %%
import pyautogui
import time
import pyperclip
pyautogui.PAUSE = 1
#passo 1: abrir o navegador
pyautogui.press("win")
pyautogui.write('chrome')
pyautogui.press("enter")
time.sleep(5)
pyautogui.hotkey("ctrl","t")
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(15)
#Passo 2: navegar até o local do dataset (pasta exportar)
pyautogui.click(x=394, y=284, clicks=2)
time.sleep(2)
#Passo 3: exportar o relatorio 
pyautogui.click(x=404, y=415)
pyautogui.click(x=1142, y=155)
pyautogui.click(x=821, y=638)
time.sleep(5)

# %%
#Passo 4: calcular os indicadores (faturamento e quantidade de produtos)
import pandas as pd

tabela = pd.read_excel(r"C:\Users\fllsa\Downloads\Vendas - Dez.xlsx")
display(tabela)

faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
print(faturamento)
print(quantidade)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %% [markdown]
# Enviar o e-mail

# %%
#Passo 5: enviar email pra diretoria
#abrir gmail
pyautogui.hotkey("ctrl","t")
pyperclip.copy("https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox") #link do gmail
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(15)
#escrever o email 
pyautogui.click(x=119, y=177)
pyautogui.write("Enderecode.email@gmail.com") #destinatário de email a ser enviado
pyautogui.click(x=975, y=353)
pyautogui.click(x=895, y=338)
pyperclip.copy("Balançeamento diário da empresa")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=786, y=395)
texto = f"""Bom dia, tudo bem?
Segue no e-mail o Faturamento de R$ {faturamento:,} e a Quantidade de {quantidade:,.2f} produtos diários da empresa, Balançeamento diário da empresa
ademais estou a disposição para maiores esclarecimentos,
Francisca Lorrayne."""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("ctrl", "enter")  #enviar email

# %%
#posição do mouse na tela
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=521, y=582)
